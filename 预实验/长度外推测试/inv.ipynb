# %%
import torch
import numpy as np
from model import make_model
from tools import Batch,CrossEntropyLossWithLabelSmoothing,get_std_opt,LossComputeAndStep,run_epoch,greedy_decode
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#为了支持多模态，允许有多个输入，但目前没有多模态的需求，默认列表中只有一条序列或者有一些等长的序列
#生成器的输入序列与输出序列类型完全一样，不支持多模态！
#为了简便，默认0为填充，1为起始标记，剩余的为正常词汇，<UNK>、<END>算作正常词汇，可以在处理数据时自由定义
#生成任务与翻译任务需要在输入序列中手动添加起始标记，使得模型能够输出更长的序列
vocab_size = 12
input_vocab_sizes = [vocab_size]
output_vocab_size = vocab_size
setting = {
    #平衡资源消耗与效果
    "enable_affine" : True,                   #加快训练速度(epoch少)，几乎不影响速度，可能影响稳定性
    "enable_layer_norm" : True,               #增强模型稳定性，略微减慢速度
    "enable_talking_head" : False,             #增强模型表达能力，严重减慢速度，消耗显存
    "enable_gated_linear_unit_in_projector" : False,  #增强模型表达能力，输出词表很小时可用，规律十分明显的时候不要用
    "self_attention_block_size" : 0,          #自注意力运算时的分块大小，可以显著降低显存消耗，提供额外的位置信息，但速度较慢
    "head_number" : 8,    #启用talking_head时数量越多效果越好，但平方消耗，否则避免过大导致key_dim过小
    "glu_projector_multivalue" : 64,          #enable_gated...启用后生效，平方复杂度
    "glu_projector_deep" : 1,                 #enable_gated...启用后生效，实验用，不建议设置更大的数值
    #模型类型选择
    "model_type" : "translator",              #经典编码器-解码器架构，适合机器翻译
    # "model_type" : "classifier",              #分类器，没有解码器，编码完总结到固定长度进行分类
    # "model_type" : "generator",               #生成器，不停的预测下一个词，可以做大模型
    # "model_type" : "vit",                     #简单的图像分类 
    "share_embeddings" : False,             #是否进行词表共享，只对"translator"有效
    "summarizer_length" : 4,                #分类器的总结长度，总结时没法分块，注意资源消耗
    "patch_size" : 16,                      #图像分块的大小，只对vit有效
    "cross_attention_block_size" : 0, #在显存不足的时候对query分段计算cross_attention，会减慢速度，逻辑上与不分块一样，只有"translator"可用
    #参数规模设置
    "embedding_dim" : 64,                   #词嵌入维度
    "key_dim" : 64,                         #解决低秩问题
    "vocab_in_size_list" : input_vocab_sizes,  #输入词表大小，支持多个输入列表，可以多模态
    "vocab_out_size" : output_vocab_size,      #输出词表大小，共享词表时不支持多模态
    "feed_forward_dim" : 256,               #注意力运算结束后用于混合不同head信息的前馈网络隐藏层维度
    "model_layers_number" : 2,              #模型的层数，注意资源消耗
    #位置信息添加方式选择
    "position_information_type" : "mask_position_information",      #掩码位置信息，如果能训练好的话可以无限外推，但可能训练有困难
    # "position_information_type" : "no_position_information",        #没有位置信息（分类器可能会用）
    # "position_information_type" : "sinusoidal_position_encoding",   #余弦位置编码（经典，高效）
    # "position_information_type" : "rotary_position_encoding",       #旋转位置编码（更好的表达相对位置）
    # "position_information_type" : "rotary_position_encoding_with_random_start", #只使用相对信息，建议用掩码
    #增加泛化能力
    "dropout_rate" : 0.1 #训练时，注意力，前馈，talking都会随机丢弃计算结果，增加泛化能力
}
model = make_model(setting).to(device)
optimizer = get_std_opt(model,fast=False)
criterion = CrossEntropyLossWithLabelSmoothing(output_vocab_size,smoothing=0.0)
weight_updater = LossComputeAndStep(criterion,optimizer)

# %%
#数据生成器
def data_generator(batch_per_epoch,batch_size,sequence_length):
    for i in range(batch_per_epoch):
        #0 代表填充、1 代表起始、2~vocab_length-1 代表正常词汇，有vocab_length-2个，np.random.randint取不到第二个参数
        np_data = np.random.randint(2,vocab_size,size=(batch_size,sequence_length+1))
        np_data[...,0] = 1
        input_sequence = torch.from_numpy(np_data[...,1:]).to(device)
        input_sequences = [input_sequence]
        np_data[...,1:] = np_data[...,1:][...,::-1]
        target_sequences = torch.from_numpy(np_data).to(device)
        yield Batch(input_sequences,target_sequences)

# %%
#训练时使用的数据格式
sequence_length = 16
batch_size = 64
batch_per_epoch = 100
num_of_epochs = 100
#训练终止标志
stop_loss = 0.01
#进行训练
for epoch in range(num_of_epochs):
    print("Epoch:",epoch)
    model.train()
    run_epoch(model,data_generator(batch_per_epoch,batch_size,sequence_length),weight_updater)
    model.eval()
    with torch.no_grad():
        if run_epoch(model,data_generator(batch_per_epoch//5,batch_size,sequence_length),weight_updater) <= stop_loss:
            break
#进行检查
model.eval()
with torch.no_grad():
    #0 代表填充、1 代表起始、2~vocab_length-1 代表正常词汇，有vocab_length-2个，np.random.randint取不到第二个参数
    check_data = np.random.randint(2,vocab_size,size=(1,sequence_length+1))
    check_data[...,0] = 1
    input_sequence = torch.from_numpy(check_data[...,1:]).to(device)
    input_sequences = [input_sequence]
    result = greedy_decode(model,input_sequences,out_length=sequence_length)
    check_data[...,1:] = check_data[...,1:][...,::-1]
    answer = torch.from_numpy(check_data[...,1:]).to(device)
    print(result)
    print(answer)
# Out:
# Epoch: 0
# Step: 0 Loss: 3.510292 Tokens per Sec: 4541.123433
# total_step: 50 lr: 4.9999999999999996e-05
# Step: 50 Loss: 3.001139 Tokens per Sec: 24809.300780
# total_step: 100 lr: 9.999999999999999e-05
# Step: 0 Loss: 2.026056 Tokens per Sec: 111456.268224
# Epoch: 1
# Step: 0 Loss: 2.121240 Tokens per Sec: 21249.170292
# total_step: 150 lr: 0.00015
# Step: 50 Loss: 1.988362 Tokens per Sec: 25115.619251
# total_step: 200 lr: 0.00019999999999999998
# Step: 0 Loss: 1.432130 Tokens per Sec: 151471.250079
# Epoch: 2
# Step: 0 Loss: 1.568961 Tokens per Sec: 25734.239058
# total_step: 250 lr: 0.00025
# Step: 50 Loss: 1.425037 Tokens per Sec: 25856.007706
# total_step: 300 lr: 0.0003
# Step: 0 Loss: 0.360265 Tokens per Sec: 82536.796818
# Epoch: 3
# Step: 0 Loss: 0.599056 Tokens per Sec: 25280.276502
# total_step: 350 lr: 0.00035
# Step: 50 Loss: 0.534541 Tokens per Sec: 25982.919842
# total_step: 400 lr: 0.00039999999999999996
# Step: 0 Loss: 0.205238 Tokens per Sec: 158878.677764
# Epoch: 4
# Step: 0 Loss: 0.377063 Tokens per Sec: 27062.242346
# total_step: 450 lr: 0.00045
# Step: 50 Loss: 0.345337 Tokens per Sec: 27214.203045
# total_step: 500 lr: 0.0005
# Step: 0 Loss: 0.097180 Tokens per Sec: 158538.529253
# Epoch: 5
# Step: 0 Loss: 0.266034 Tokens per Sec: 25884.679986
# total_step: 550 lr: 0.0005499999999999999
# Step: 50 Loss: 0.270397 Tokens per Sec: 25360.609330
# total_step: 600 lr: 0.0006
# Step: 0 Loss: 0.125221 Tokens per Sec: 158720.151367
# Epoch: 6
# Step: 0 Loss: 0.220524 Tokens per Sec: 27522.314686
# total_step: 650 lr: 0.00065
# Step: 50 Loss: 0.221956 Tokens per Sec: 24791.483255
# total_step: 700 lr: 0.0007
# Step: 0 Loss: 0.090289 Tokens per Sec: 148923.970042
# Epoch: 7
# Step: 0 Loss: 0.180961 Tokens per Sec: 27162.020288
# total_step: 750 lr: 0.00075
# Step: 50 Loss: 0.180715 Tokens per Sec: 25033.711521
# total_step: 800 lr: 0.0007999999999999999
# Step: 0 Loss: 0.053471 Tokens per Sec: 139347.456233
# Epoch: 8
# Step: 0 Loss: 0.155623 Tokens per Sec: 25820.411783
# total_step: 850 lr: 0.00085
# Step: 50 Loss: 0.153902 Tokens per Sec: 25090.538663
# total_step: 900 lr: 0.0009
# Step: 0 Loss: 0.061208 Tokens per Sec: 145606.919212
# Epoch: 9
# Step: 0 Loss: 0.151406 Tokens per Sec: 25189.980798
# total_step: 950 lr: 0.00095
# Step: 50 Loss: 0.142160 Tokens per Sec: 24701.283556
# total_step: 1000 lr: 0.001
# Step: 0 Loss: 0.052799 Tokens per Sec: 132934.083259
# Epoch: 10
# Step: 0 Loss: 0.125517 Tokens per Sec: 24940.724221
# total_step: 1050 lr: 0.00105
# Step: 50 Loss: 0.118414 Tokens per Sec: 24925.861948
# total_step: 1100 lr: 0.0010999999999999998
# Step: 0 Loss: 0.091909 Tokens per Sec: 148614.785329
# Epoch: 11
# Step: 0 Loss: 0.136050 Tokens per Sec: 26002.054123
# total_step: 1150 lr: 0.00115
# Step: 50 Loss: 0.124260 Tokens per Sec: 26454.808720
# total_step: 1200 lr: 0.0012
# Step: 0 Loss: 0.055233 Tokens per Sec: 148224.989509
# Epoch: 12
# Step: 0 Loss: 0.119839 Tokens per Sec: 25788.319790
# total_step: 1250 lr: 0.00125
# Step: 50 Loss: 0.115205 Tokens per Sec: 25709.084061
# total_step: 1300 lr: 0.0013
# Step: 0 Loss: 0.047297 Tokens per Sec: 144782.312355
# Epoch: 13
# Step: 0 Loss: 0.093712 Tokens per Sec: 25545.818043
# total_step: 1350 lr: 0.0013499999999999999
# Step: 50 Loss: 0.109080 Tokens per Sec: 24846.447186
# total_step: 1400 lr: 0.0014
# Step: 0 Loss: 0.070248 Tokens per Sec: 91667.035813
# Epoch: 14
# Step: 0 Loss: 0.098790 Tokens per Sec: 24875.000266
# total_step: 1450 lr: 0.00145
# Step: 50 Loss: 0.101489 Tokens per Sec: 25261.678254
# total_step: 1500 lr: 0.0015
# Step: 0 Loss: 0.065121 Tokens per Sec: 145913.616307
# Epoch: 15
# Step: 0 Loss: 0.103020 Tokens per Sec: 24532.576860
# total_step: 1550 lr: 0.00155
# Step: 50 Loss: 0.095948 Tokens per Sec: 25221.201285
# lr restart at step: 1562, lr: 0.001563, new_loss: 0.167340 > mid_loss: 0.163902
# total_step: 1600 lr: 3.7999999999999995e-05
# Step: 0 Loss: 0.058364 Tokens per Sec: 149192.972627
# Epoch: 16
# Step: 0 Loss: 0.109512 Tokens per Sec: 25449.546681
# total_step: 1650 lr: 8.8e-05
# Step: 50 Loss: 0.070173 Tokens per Sec: 25836.431800
# total_step: 1700 lr: 0.000138
# Step: 0 Loss: 0.021774 Tokens per Sec: 142099.827825
# Epoch: 17
# Step: 0 Loss: 0.036394 Tokens per Sec: 25770.679979
# total_step: 1750 lr: 0.000188
# Step: 50 Loss: 0.050889 Tokens per Sec: 25613.688346
# total_step: 1800 lr: 0.00023799999999999998
# Step: 0 Loss: 0.013403 Tokens per Sec: 137743.090215
# Epoch: 18
# Step: 0 Loss: 0.047977 Tokens per Sec: 24106.954283
# total_step: 1850 lr: 0.000288
# Step: 50 Loss: 0.048851 Tokens per Sec: 24492.917450
# total_step: 1900 lr: 0.000338
# Step: 0 Loss: 0.018577 Tokens per Sec: 134634.252719
# Epoch: 19
# Step: 0 Loss: 0.059639 Tokens per Sec: 25248.770155
# total_step: 1950 lr: 0.000388
# Step: 50 Loss: 0.049609 Tokens per Sec: 24808.764821
# total_step: 2000 lr: 0.00043799999999999997
# Step: 0 Loss: 0.023220 Tokens per Sec: 142081.024711
# Epoch: 20
# Step: 0 Loss: 0.040876 Tokens per Sec: 25125.730793
# total_step: 2050 lr: 0.000488
# Step: 50 Loss: 0.048757 Tokens per Sec: 24977.603125
# total_step: 2100 lr: 0.000538
# Step: 0 Loss: 0.023904 Tokens per Sec: 135839.309760
# Epoch: 21
# Step: 0 Loss: 0.046587 Tokens per Sec: 25091.382963
# total_step: 2150 lr: 0.000588
# Step: 50 Loss: 0.049949 Tokens per Sec: 24919.183461
# total_step: 2200 lr: 0.000638
# Step: 0 Loss: 0.010134 Tokens per Sec: 147694.886382
# Epoch: 22
# Step: 0 Loss: 0.051347 Tokens per Sec: 24734.468398
# total_step: 2250 lr: 0.0006879999999999999
# Step: 50 Loss: 0.057925 Tokens per Sec: 25468.262603
# total_step: 2300 lr: 0.0007379999999999999
# Step: 0 Loss: 0.023317 Tokens per Sec: 132613.928305
# Epoch: 23
# Step: 0 Loss: 0.057696 Tokens per Sec: 25915.292227
# total_step: 2350 lr: 0.000788
# Step: 50 Loss: 0.060054 Tokens per Sec: 24487.996263
# total_step: 2400 lr: 0.000838
# Step: 0 Loss: 0.013836 Tokens per Sec: 143793.474706
# Epoch: 24
# Step: 0 Loss: 0.041144 Tokens per Sec: 24264.392346
# total_step: 2450 lr: 0.000888
# Step: 50 Loss: 0.066135 Tokens per Sec: 24787.128001
# total_step: 2500 lr: 0.0009379999999999999
# Step: 0 Loss: 0.055290 Tokens per Sec: 124973.587919
# Epoch: 25
# Step: 0 Loss: 0.076276 Tokens per Sec: 25057.275101
# total_step: 2550 lr: 0.000988
# Step: 50 Loss: 0.061528 Tokens per Sec: 25032.153279
# total_step: 2600 lr: 0.0010379999999999999
# Step: 0 Loss: 0.030173 Tokens per Sec: 100148.470270
# Epoch: 26
# Step: 0 Loss: 0.086757 Tokens per Sec: 21243.284677
# total_step: 2650 lr: 0.001088
# Step: 50 Loss: 0.067671 Tokens per Sec: 22892.944506
# total_step: 2700 lr: 0.001138
# Step: 0 Loss: 0.040585 Tokens per Sec: 155614.757101
# Epoch: 27
# Step: 0 Loss: 0.043441 Tokens per Sec: 26555.583492
# total_step: 2750 lr: 0.001188
# Step: 50 Loss: 0.071857 Tokens per Sec: 25745.015445
# total_step: 2800 lr: 0.001238
# Step: 0 Loss: 0.029322 Tokens per Sec: 147335.161607
# Epoch: 28
# Step: 0 Loss: 0.060469 Tokens per Sec: 26983.522624
# total_step: 2850 lr: 0.0012879999999999999
# Step: 50 Loss: 0.101888 Tokens per Sec: 26109.452241
# total_step: 2900 lr: 0.001338
# Step: 0 Loss: 0.034072 Tokens per Sec: 157221.147083
# Epoch: 29
# Step: 0 Loss: 0.073323 Tokens per Sec: 27149.143142
# total_step: 2950 lr: 0.001388
# Step: 50 Loss: 0.075085 Tokens per Sec: 25589.070220
# lr restart at step: 2967, lr: 0.001406, new_loss: 0.074097 > mid_loss: 0.067146
# total_step: 3000 lr: 3.2999999999999996e-05
# Step: 0 Loss: 0.023407 Tokens per Sec: 155755.840290
# Epoch: 30
# Step: 0 Loss: 0.047340 Tokens per Sec: 26622.083146
# total_step: 3050 lr: 8.3e-05
# Step: 50 Loss: 0.042944 Tokens per Sec: 25137.963085
# total_step: 3100 lr: 0.000133
# Step: 0 Loss: 0.013193 Tokens per Sec: 157042.937438
# Epoch: 31
# Step: 0 Loss: 0.045534 Tokens per Sec: 26508.053054
# total_step: 3150 lr: 0.000183
# Step: 50 Loss: 0.034599 Tokens per Sec: 26544.131119
# total_step: 3200 lr: 0.000233
# Step: 0 Loss: 0.011789 Tokens per Sec: 156271.550575
# Epoch: 32
# Step: 0 Loss: 0.056488 Tokens per Sec: 26870.247909
# total_step: 3250 lr: 0.000283
# Step: 50 Loss: 0.033216 Tokens per Sec: 26556.099064
# total_step: 3300 lr: 0.00033299999999999996
# Step: 0 Loss: 0.009544 Tokens per Sec: 156916.710971
# tensor([[ 5,  9, 10,  3, 11,  8, 10,  6, 11,  3,  6, 10,  6,  4,  3,  9]],
#        device='cuda:0')
# tensor([[ 5,  9, 10,  3, 11,  8, 10,  6, 11,  3,  6, 10,  6,  4,  3,  9]],
#        device='cuda:0')

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.close()
plt.plot(weight_updater.recorder.train_loss_line_per_epoch)
plt.plot(weight_updater.recorder.test_loss_line_per_epoch)

# %%
plt.close()
plt.plot(weight_updater.recorder.train_loss_line)

# %%
plt.close()
plt.plot(weight_updater.recorder.test_loss_line)

# %%
plt.close()
plt.plot(weight_updater.recorder.mean_loss_line)

# %%
torch.save(model.state_dict(),'inv_12.weight')
